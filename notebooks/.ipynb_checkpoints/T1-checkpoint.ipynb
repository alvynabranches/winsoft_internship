# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_json('../data.json')
# Out:
#                                                         rates   start_at base  \
# 2019-01-02  {'CAD': 1.5547, 'HKD': 8.9294, 'ISK': 133.4, '... 2019-01-01  EUR
# 2019-01-03  {'CAD': 1.5392000000000001, 'HKD': 8.8884, 'IS... 2019-01-01  EUR
# 2019-01-04  {'CAD': 1.5328, 'HKD': 8.9325, 'ISK': 134.0, '... 2019-01-01  EUR
# 2019-01-07  {'CAD': 1.5281, 'HKD': 8.9677, 'ISK': 135.2, '... 2019-01-01  EUR
# 2019-01-08  {'CAD': 1.5208, 'HKD': 8.9671, 'ISK': 136.1, '... 2019-01-01  EUR
# ...                                                       ...        ...  ...
# 2019-12-23  {'CAD': 1.4577, 'HKD': 8.6232, 'ISK': 135.4, '... 2019-01-01  EUR
# 2019-12-24  {'CAD': 1.4582, 'HKD': 8.629, 'ISK': 135.6, 'P... 2019-01-01  EUR
# 2019-12-27  {'CAD': 1.4592, 'HKD': 8.6845, 'ISK': 135.6, '... 2019-01-01  EUR
# 2019-12-30  {'CAD': 1.4621, 'HKD': 8.7133, 'ISK': 135.8, '... 2019-01-01  EUR
# 2019-12-31  {'CAD': 1.4598, 'HKD': 8.7473, 'ISK': 135.8, '... 2019-01-01  EUR
#
#                end_at
# 2019-01-02 2019-12-31
# 2019-01-03 2019-12-31
# 2019-01-04 2019-12-31
# 2019-01-07 2019-12-31
# 2019-01-08 2019-12-31
# ...               ...
# 2019-12-23 2019-12-31
# 2019-12-24 2019-12-31
# 2019-12-27 2019-12-31
# 2019-12-30 2019-12-31
# 2019-12-31 2019-12-31
#
# [255 rows x 4 columns]

# %%
pd.read_json('../data.json')['rates']
# Out:
# 2019-01-02    {'CAD': 1.5547, 'HKD': 8.9294, 'ISK': 133.4, '...
# 2019-01-03    {'CAD': 1.5392000000000001, 'HKD': 8.8884, 'IS...
# 2019-01-04    {'CAD': 1.5328, 'HKD': 8.9325, 'ISK': 134.0, '...
# 2019-01-07    {'CAD': 1.5281, 'HKD': 8.9677, 'ISK': 135.2, '...
# 2019-01-08    {'CAD': 1.5208, 'HKD': 8.9671, 'ISK': 136.1, '...
#                                     ...
# 2019-12-23    {'CAD': 1.4577, 'HKD': 8.6232, 'ISK': 135.4, '...
# 2019-12-24    {'CAD': 1.4582, 'HKD': 8.629, 'ISK': 135.6, 'P...
# 2019-12-27    {'CAD': 1.4592, 'HKD': 8.6845, 'ISK': 135.6, '...
# 2019-12-30    {'CAD': 1.4621, 'HKD': 8.7133, 'ISK': 135.8, '...
# 2019-12-31    {'CAD': 1.4598, 'HKD': 8.7473, 'ISK': 135.8, '...
# Name: rates, Length: 255, dtype: object

# %%
pd.read_json('../data.json')['rates'][0]
# Out:
# {'CAD': 1.5547,
#  'HKD': 8.9294,
#  'ISK': 133.4,
#  'PHP': 59.894,
#  'DKK': 7.4669,
#  'HUF': 322.37,
#  'CZK': 25.752,
#  'AUD': 1.6273,
#  'RON': 4.66,
#  'SEK': 10.2145,
#  'IDR': 16484.11,
#  'INR': 79.9855,
#  'BRL': 4.393,
#  'RUB': 79.3589,
#  'HRK': 7.4205,
#  'JPY': 124.28,
#  'THB': 36.807,
#  'CHF': 1.1239,
#  'SGD': 1.5554999999999999,
#  'PLN': 4.2964,
#  'BGN': 1.9558,
#  'TRY': 6.113,
#  'CNY': 7.8165,
#  'NOK': 9.9108,
#  'NZD': 1.7049,
#  'ZAR': 16.5075,
#  'USD': 1.1397,
#  'MXN': 22.3941,
#  'ILS': 4.2708,
#  'GBP': 0.9016500000000001,
#  'KRW': 1278.52,
#  'MYR': 4.7195}

# %%
df = pd.read_json('../data.json')

# %%
df
# Out:
#                                                         rates   start_at base  \
# 2019-01-02  {'CAD': 1.5547, 'HKD': 8.9294, 'ISK': 133.4, '... 2019-01-01  EUR
# 2019-01-03  {'CAD': 1.5392000000000001, 'HKD': 8.8884, 'IS... 2019-01-01  EUR
# 2019-01-04  {'CAD': 1.5328, 'HKD': 8.9325, 'ISK': 134.0, '... 2019-01-01  EUR
# 2019-01-07  {'CAD': 1.5281, 'HKD': 8.9677, 'ISK': 135.2, '... 2019-01-01  EUR
# 2019-01-08  {'CAD': 1.5208, 'HKD': 8.9671, 'ISK': 136.1, '... 2019-01-01  EUR
# ...                                                       ...        ...  ...
# 2019-12-23  {'CAD': 1.4577, 'HKD': 8.6232, 'ISK': 135.4, '... 2019-01-01  EUR
# 2019-12-24  {'CAD': 1.4582, 'HKD': 8.629, 'ISK': 135.6, 'P... 2019-01-01  EUR
# 2019-12-27  {'CAD': 1.4592, 'HKD': 8.6845, 'ISK': 135.6, '... 2019-01-01  EUR
# 2019-12-30  {'CAD': 1.4621, 'HKD': 8.7133, 'ISK': 135.8, '... 2019-01-01  EUR
# 2019-12-31  {'CAD': 1.4598, 'HKD': 8.7473, 'ISK': 135.8, '... 2019-01-01  EUR
#
#                end_at
# 2019-01-02 2019-12-31
# 2019-01-03 2019-12-31
# 2019-01-04 2019-12-31
# 2019-01-07 2019-12-31
# 2019-01-08 2019-12-31
# ...               ...
# 2019-12-23 2019-12-31
# 2019-12-24 2019-12-31
# 2019-12-27 2019-12-31
# 2019-12-30 2019-12-31
# 2019-12-31 2019-12-31
#
# [255 rows x 4 columns]

# %%
df['rates'][0]['INR']
# Out:
# 79.9855

# %%
data = pd.DataFrame(columns=['date', 'base', 'start_at', 'end_at'])
for rate, date, n, base, start_at, end_at in zip(df['rates'], df.index, range(df.shape[0]), df['base'], df['start_at'], df['end_at']):
    data = data.append({k:rate[k] for k in rate}, ignore_index=True)
    data['date'][n] = date
    data['base'][n] = base
    data['start_at'][n] = start_at
    data['end_at'][n] = end_at
data.index = data['date']
data.drop(['date'], axis=1, inplace=True)
data['start_at'] = data['start_at'].astype('datetime64[D]')
data['end_at'] = data['end_at'].astype('datetime64[D]')
# Out:
# <ipython-input-48-0d15379be50a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'][n] = date
# <ipython-input-48-0d15379be50a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['base'][n] = base
# <ipython-input-48-0d15379be50a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['start_at'][n] = start_at
# <ipython-input-48-0d15379be50a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data